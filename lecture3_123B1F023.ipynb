# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %%
image = Image.open('nature_image.jpeg')
image.show()

# %%
print(image.size)
# Out:
# (357, 200)

# %%
print(image.format)
# Out:
# JPEG

# %%
print(image.mode)
# Out:
# RGB

# %%
resized_image = image.resize((200,200))
resized_image.show()

# %%
cropped_image = image.crop((50,50,150,150))
cropped_image.show()

# %%
rotate_image = image.rotate(30)
rotate_image.show()

# %%
from PIL import Image,ImageDraw,ImageFont

# %%
cat_img = Image.open(r'cat_img.png')
cat_img.show()

# %%
draw = ImageDraw.Draw(cat_img)
font = ImageFont.truetype("arial.ttf", 100)
text = "Meowwww!!!!"
position = (50, 50)
color = (150,150,0)
draw.text(position, text, fill=color, font=font)
cat_img.show()

# %%
from PIL import ImageEnhance

# %%
lion_img = Image.open("lion_img.png")
lion_img.show()
enhancer = ImageEnhance.Brightness(lion_img)
brightened_image = enhancer.enhance(1.5)
enhancer = ImageEnhance.Contrast(brightened_image)
contrasted_image = enhancer.enhance(1.2)
# Display the enhanced image
contrasted_image.show()
